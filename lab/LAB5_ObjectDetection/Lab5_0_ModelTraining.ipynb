# %% [markdown]
# # Ultralytics Platform Setup
# ## 1️⃣ Create an Account
#
# Go to:
# https://platform.ultralytics.com/
#
# Sign in (Google or email).
#
# ## 2️⃣ Generate Your API Key
#
# Click Profile → Settings
#
# Select API Keys
#
# Click Create API Key
#
# Copy the generated key
#
# ⚠️ Keep your API key private. Do not share or upload it to GitHub.
#
# ## 3️⃣ Set the API Key in Colab (Recommended Method)
# Step A: Store as Colab Secret
#
# Click the 🔑 Secrets panel in Colab
#
# Click Add new secret
#
# Name:
#
# ULTRALYTICS_API_KEY
#
#
# Paste your API key as the value
#
# Enable Notebook access

# %%
# !pip -q install ultralytics

# %%
import os
from google.colab import userdata

os.environ["ULTRALYTICS_API_KEY"] = userdata.get("ULTRALYTICS_API_KEY")
print("Key loaded?", os.environ.get("ULTRALYTICS_API_KEY") is not None)
# Out:
# Key loaded? True

# %%
# !yolo train \
  model="yolo26n.pt" \
  data="ul://thethee/datasets/polyp-detect" \
  epochs=100 \
  batch=16 \
  imgsz=320 \
  project="thethee/polypdetection"
# Out:
# ...
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...
